# %% [markdown]
# <a href="https://colab.research.google.com/github/grammukuttyma103-stack/Data-Analytics-using-Python-Project/blob/main/DAY1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
mark1 = int(input("Enter Mark 1: "))
mark2 = int(input("Enter Mark 2: "))
mark3 = int(input("Enter Mark 3: "))

total = mark1 + mark2 + mark3
average = total / 3

print("Total:", total)
print("Average:", average)

if average >= 50:
    print("Pass")
else:
    print("Fail")
# Out:
# Enter Mark 1: 98
# Enter Mark 2: 34
# Enter Mark 3: 76
# Total: 208
# Average: 69.33333333333333
# Pass
