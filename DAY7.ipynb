# %% [markdown]
# <a href="https://colab.research.google.com/github/grammukuttyma103-stack/Data-Analytics-using-Python-Project/blob/main/DAY7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

employees = {
    "Emp_ID": [101, 102, 103, 104, 105],
    "Name": ["Arun", "Priya", "Rahul", "Divya", "Kumar"],
    "Department": ["IT", "HR", "IT", "Finance", "HR"],
    "Salary": [45000, 40000, 50000, 55000, 42000],
    "Experience": [2, 3, 5, 6, 4]
}

df = pd.DataFrame(employees)

print("Employee Dataset")
print(df)

print("\nAverage Salary")
print(df["Salary"].mean())

print("\nHighest Salary")
print(df["Salary"].max())

print("\nEmployees in HR")
print(df[df["Department"] == "HR"])

print("\nEmployees with Experience > 3")
print(df[df["Experience"] > 3])

print("\nEmployee Count by Department")
print(df["Department"].value_counts())
# Out:
# Employee Dataset
#    Emp_ID   Name Department  Salary  Experience
# 0     101   Arun         IT   45000           2
# 1     102  Priya         HR   40000           3
# 2     103  Rahul         IT   50000           5
# 3     104  Divya    Finance   55000           6
# 4     105  Kumar         HR   42000           4
#
# Average Salary
# 46400.0
#
# Highest Salary
# 55000
#
# Employees in HR
#    Emp_ID   Name Department  Salary  Experience
# 1     102  Priya         HR   40000           3
# 4     105  Kumar         HR   42000           4
#
# Employees with Experience > 3
#    Emp_ID   Name Department  Salary  Experience
# 2     103  Rahul         IT   50000           5
# 3     104  Divya    Finance   55000           6
# 4     105  Kumar         HR   42000           4
#
# Employee Count by Department
# Department
# IT         2
# HR         2
# Finance    1
# Name: count, dtype: int64

# %%
import pandas as pd

data = {
    'Name': ['John', 'Mary', 'John'],
    'Sales': [1000, 1500, 1000]
}

df = pd.DataFrame(data)

print(df.duplicated())
# Out:
# 0    False
# 1    False
# 2     True
# dtype: bool

# %%
import pandas as pd

data = {
    'emp_nm': ['John', 'Mary'],
    'emp_sal': [25000, 30000]
}

df = pd.DataFrame(data)

df.rename(columns={
    'emp_nm': 'Employee Name',
    'emp_sal': 'Employee Salary'
}, inplace=True)

print(df)
# Out:
#   Employee Name  Employee Salary
# 0          John            25000
# 1          Mary            30000

# %%
import pandas as pd

data = {
    "Region":["South","North","West","Eest","South","North"],
    "Product":["Laptop","Mobile","Laptop","Tabels","Mobiles","Tablets"],
    "Sales":[5000,3000,4500,2500,2000,3500]
}

df= pd.DataFrame(data)

print(df)
# Out:
#   Region  Product  Sales
# 0  South   Laptop   5000
# 1  North   Mobile   3000
# 2   West   Laptop   4500
# 3   Eest   Tabels   2500
# 4  South  Mobiles   2000
# 5  North  Tablets   3500

# %%
south_sales=df[df["Region"]=="South"]

print(south_sales)
# Out:
#   Region  Product  Sales
# 0  South   Laptop   5000
# 4  South  Mobiles   2000

# %%
sorted_df = df.sort_values("Sales")

print(sorted_df)
# Out:
#   Region  Product  Sales
# 4  South  Mobiles   2000
# 3   Eest   Tabels   2500
# 1  North   Mobile   3000
# 5  North  Tablets   3500
# 2   West   Laptop   4500
# 0  South   Laptop   5000
