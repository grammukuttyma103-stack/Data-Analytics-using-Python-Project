# %% [markdown]
# <a href="https://colab.research.google.com/github/grammukuttyma103-stack/Data-Analytics-using-Python-Project/blob/main/DAY_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

marks = np.array([98,86,79,80])

print(marks[3])
# Out:
# 80

# %%
import numpy as np

marks = np.array([98,86,79,80])

print(marks[1:3])
# Out:
# [86 79]

# %%
import numpy as np

arr=np.array([1,2,3,4,5,6])

new_arr=arr.reshape(2,3)

print(new_arr)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
import numpy as np

marks=np.array([87,90,93,95])

average=np.mean(marks)

print(average)
# Out:
# 91.25

# %%
salary =np.array([100,200,300,400,500])


med=np.median(salary)

print(med)
# Out:
# 300.0

# %%
scores = [85, 90, 78, 92, 88]

print("Scores:", scores)
print("Total:", sum(scores))
print("Average:", sum(scores)/len(scores))
print("Highest:", max(scores))
print("Lowest:", min(scores))
# Out:
# Scores: [85, 90, 78, 92, 88]
# Total: 433
# Average: 86.6
# Highest: 92
# Lowest: 78
