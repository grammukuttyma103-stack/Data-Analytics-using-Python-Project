# %% [markdown]
# <a href="https://colab.research.google.com/github/grammukuttyma103-stack/Data-Analytics-using-Python-Project/blob/main/mini_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import pandas as pd
import matplotlib.pyplot  as plt

uploaded=files.upload()


df=pd.read_csv("Student.csv")

print(df)
# Out:
#      <input type="file" id="files-14ef0f27-0728-474a-a480-16a82dd1ab63" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-14ef0f27-0728-474a-a480-16a82dd1ab63">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.head(20)
# Out:
#    gender,race/ethnicity,parental level of education,lunch,test preparation course,math score,reading score,writing score
# 0   female,group B,bachelor's degree,standard,none...
# 1   female,group C,some college,standard,completed...
# 2   female,group B,master's degree,standard,none,9...
# 3   male,group A,associate's degree,free/reduced,n...
# 4    male,group C,some college,standard,none,76,78,75
# 5   female,group B,associate's degree,standard,non...
# 6   female,group B,some college,standard,completed...
# 7   male,group B,some college,free/reduced,none,40...
# 8   male,group D,high school,free/reduced,complete...
# 9   female,group B,high school,free/reduced,none,3...
# 10  male,group C,associate's degree,standard,none,...
# 11  male,group D,associate's degree,standard,none,...
# 12  female,group B,high school,standard,none,65,81,73
# 13  male,group A,some college,standard,completed,7...
# 14  female,group A,master's degree,standard,none,5...
# ...

# %%
print(df.isnull().sum())
# Out:
# gender,race/ethnicity,parental level of education,lunch,test preparation course,math score,reading score,writing score    0
# dtype: int64

# %%
print(df.shape)
# Out:
# (20, 1)

# %%
df=df.drop_duplicates()
print(df)
# Out:
#    gender,race/ethnicity,parental level of education,lunch,test preparation course,math score,reading score,writing score
# 0   female,group B,bachelor's degree,standard,none...
# 1   female,group C,some college,standard,completed...
# 2   female,group B,master's degree,standard,none,9...
# 3   male,group A,associate's degree,free/reduced,n...
# 4    male,group C,some college,standard,none,76,78,75
# 5   female,group B,associate's degree,standard,non...
# 6   female,group B,some college,standard,completed...
# 7   male,group B,some college,free/reduced,none,40...
# 8   male,group D,high school,free/reduced,complete...
# 9   female,group B,high school,free/reduced,none,3...
# 10  male,group C,associate's degree,standard,none,...
# 11  male,group D,associate's degree,standard,none,...
# 12  female,group B,high school,standard,none,65,81,73
# 13  male,group A,some college,standard,completed,7...
# 14  female,group A,master's degree,standard,none,5...
# ...
