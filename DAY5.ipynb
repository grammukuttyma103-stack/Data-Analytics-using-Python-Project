# %% [markdown]
# <a href="https://colab.research.google.com/github/grammukuttyma103-stack/Data-Analytics-using-Python-Project/blob/main/DAY5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sales = [1000,2000,3000,4000, 5000]

print("Sales:", sales)
print("Total:", sum(sales))
print("Average:", sum(sales)/len(sales))
print("Highest:", max(sales))
print("Lowest:", min(sales))
# Out:
# Sales: [1000, 2000, 3000, 4000, 5000]
# Total: 15000
# Average: 3000.0
# Highest: 5000
# Lowest: 1000

# %%
import pandas as pd

data =pd.Series([10,20,30,40])

print(data)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
import pandas as pd

data=pd.Series(
    [100,200,300],
    index=["RAMYA","LOGA","RAHIMA"]
)
print(data)
# Out:
# RAMYA     100
# LOGA      200
# RAHIMA    300
# dtype: int64

# %%
import pandas as pd

employee={
    "ID":[101,102,103],
    "NAME":["RAMYA","LOGA","RAHIMA"],
    "Salary":[19000,10000,15000]
}

df=pd.DataFrame(employee)

print(df)
# Out:
#     ID    NAME  Salary
# 0  101   RAMYA   19000
# 1  102    LOGA   10000
# 2  103  RAHIMA   15000
